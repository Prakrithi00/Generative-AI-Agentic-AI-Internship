# %%
pip install -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (4.2.4)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai) (2.8.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai) (1.4.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.12.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.2)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (48.0.0)
# Requirement already satisfied: certifi in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.8.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.4.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = "Enter your API key here"

# Initialize the chat model
model = ChatGoogleGenerativeAI(model="gemini-3.5-flash")
response = model.invoke("Tabular data of Generative AI vs Agentic AI")
print(response.text)
# Out:
# Here is a detailed tabular comparison of **Generative AI** and **Agentic AI**.
#
# While Generative AI is focused on **content creation**, Agentic AI is focused on **autonomous action**. In many ways, Agentic AI represents the next evolution of Generative AI, using Large Language Models (LLMs) as its "brain" to make decisions and execute tasks.
#
# ### Generative AI vs. Agentic AI
#
# | Feature / Criteria | Generative AI | Agentic AI |
# | :--- | :--- | :--- |
# | **Core Definition** | AI designed to generate new content (text, images, audio, code) based on patterns in training data. | AI designed to act as an autonomous agent to achieve specific goals through planning, reasoning, and tool use. |
# | **Primary Goal** | **Creation and Synthesis** (e.g., "Write an email," "Draw a picture"). | **Execution and Automation** (e.g., "Analyze this spreadsheet, find anomalies, and email the client"). |
# | **Operational Mode** | **Input $\rightarrow$ Output** (Single-turn interactions; responsive). | **Goal $\rightarrow$ Plan $\rightarrow$ Execute $\rightarrow$ Evaluate $\rightarrow$ Adapt** (Multi-step, iterative loops). |
# | **Level of Autonomy** | **Low to Medium**: Requires constant human prompting and steering to achieve a final result. | **High**: Operates independently once given a goal; can self-correct and make decisions. |
# | **Core Capabilities** | Pattern matching, translation, summarization, creative writing, image generation. | Task planning, reasoning, decision-making, memory retention, tool usage. |
# | **Tool Integration** | Limited. Mostly relies on the internal knowledge base of the model. | Extensive. Can use APIs, web browsers, databases, calculators, and other software tools. |
# | **Memory & State** | **Stateless**: Generally forgets previous prompts unless within the same chat context window. | **Stateful**: Possesses short-term (working memory for the task) and long-term memory (recalling past interactions and outcomes). |
# | **Human Interaction** | **Co-pilot**: Human guides the AI step-by-step. | **Manager/Supervisor**: Human sets the goal and approves final actions (human-in-the-loop). |
# | **Workflow** | **Linear**: Prompt $\rightarrow$ Answer. | **Dynamic/Looped**: Perceives environment $\rightarrow$ Decides on action $\rightarrow$ Executes $\rightarrow$ Analyzes feedback. |
# | **Response to Errors** | Generates a plausible-sounding wrong answer (Hallucination) unless corrected by the user. | Detects failure (e.g., a broken API link), self-corrects, and tries an alternative path. |
# | **Key Examples** | ChatGPT (basic text), Midjourney (images), GitHub Copilot (code generation). | AutoGPT, Devin (AI Software Engineer), CrewAI, autonomous customer support agents. |
# | **Primary Limitations** | Hallucinations, lack of real-time world knowledge, inability to take action on behalf of the user. | "Infinite loops" (getting stuck in a task), high token consumption (expensive), security risks of autonomous actions. |
#
# ---
#
# ### Key Takeaway: The Evolutionary Relationship
# * **Generative AI is the "Brain":** It understands language, reasons, and generates ideas.
# * **Agentic AI is the "Hands and Feet":** It takes that brain, connects it to tools (like email, databases, and web browsers), and gives it the autonomy to complete complex, multi-step jobs without human hand-holding.
