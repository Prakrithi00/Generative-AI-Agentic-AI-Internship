# %%
# !pip install -U langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (1.4.1)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (2.41.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.8.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (2.32.3)
# Requirement already satisfied: websockets>=15.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (4.12.0)
# Requirement already satisfied: certifi in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.15.0)
# Requirement already satisfied: sniffio in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.0->langchain-openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.0->langchain-openai) (0.4.2)
# Requirement already satisfied: regex in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.5.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-openai) (2.4.0)
# Requirement already satisfied: colorama in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain.chat_models import init_chat_model
# Set up the OpenAI API key
os.environ["OPENAI_API_KEY"] = "Enter your API key here"
# Initialize the chat model
model = init_chat_model("gpt-5.2")
response = model.invoke("Tell me about India economy")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[15], line 7
#       5 # Initialize the chat model
#       6 model = init_chat_model("gpt-5.2")
# ----> 7 response = model.invoke("Tell me about India economy")
#       8 print(response.text)
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1847, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1838 @override
#    1839 def generate_prompt(
#    1840     self,
#    (...)   1844     **kwargs: Any,
#    1845 ) -> LLMResult:
#    1846     prompt_messages = [p.to_messages() for p in prompts]
# -> 1847     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1654, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1651 for i, m in enumerate(input_messages):
#    1652     try:
#    1653         results.append(
# -> 1654             self._generate_with_cache(
#    1655                 m,
#    1656                 stop=stop,
#    1657                 run_manager=run_managers[i] if run_managers else None,
#    1658                 **kwargs,
#    1659             )
#    1660         )
#    1661     except BaseException as e:
#    1662         if run_managers:
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1667, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1665     _handle_openai_bad_request(e)
#    1666 except openai.APIError as e:
# -> 1667     _handle_openai_api_error(e)
#    1668 except Exception as e:
#    1669     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1662, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1655         return _construct_lc_result_from_responses_api(
#    1656             response,
#    1657             schema=original_schema_obj,
#    1658             metadata=generation_info,
#    1659             output_version=self.output_version,
#    1660         )
#    1661     else:
# -> 1662         raw_response = self.client.with_raw_response.create(**payload)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
