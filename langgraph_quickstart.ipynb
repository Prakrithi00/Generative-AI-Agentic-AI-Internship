# %%
pip install -U langgraph
# Out:
# Requirement already satisfied: langgraph in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.4)
# Collecting langgraph
#   Downloading langgraph-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2,>=1.4.7 (from langgraph)
#   Downloading langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph) (3.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2,>=1.4.7->langgraph)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.8.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (4.12.0)
# Requirement already satisfied: certifi in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.4.0)
# Downloading langgraph-1.2.6-py3-none-any.whl (246 kB)
# Downloading langchain_core-1.4.8-py3-none-any.whl (557 kB)
#    ---------------------------------------- 0.0/557.4 kB ? eta -:--:--
#    ---------------------------------------- 557.4/557.4 kB 7.9 MB/s  0:00:00
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Installing collected packages: langchain-protocol, langchain-core, langgraph
#
#   Attempting uninstall: langchain-protocol
#
#     Found existing installation: langchain-protocol 0.0.16
#
#    ---------------------------------------- 0/3 [langchain-protocol]
#     Uninstalling langchain-protocol-0.0.16:
#    ---------------------------------------- 0/3 [langchain-protocol]
#       Successfully uninstalled langchain-protocol-0.0.16
#    ---------------------------------------- 0/3 [langchain-protocol]
#    ---------------------------------------- 0/3 [langchain-protocol]
#    ---------------------------------------- 0/3 [langchain-protocol]
#    ---------------------------------------- 0/3 [langchain-protocol]
#   Attempting uninstall: langchain-core
#    ---------------------------------------- 0/3 [langchain-protocol]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#     Found existing installation: langchain-core 1.4.1
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#     Uninstalling langchain-core-1.4.1:
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#       Successfully uninstalled langchain-core-1.4.1
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#   Attempting uninstall: langgraph
#    ------------- -------------------------- 1/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langgraph]
#     Found existing installation: langgraph 1.2.4
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#     Uninstalling langgraph-1.2.4:
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#       Successfully uninstalled langgraph-1.2.4
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    ---------------------------------------- 3/3 [langgraph]
#
# Successfully installed langchain-core-1.4.8 langchain-protocol-0.0.18 langgraph-1.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from IPython.display import Image, display

# %%
class MyState(TypedDict):
    message: str

# Define the start node
def start_node(state: MyState) -> MyState:
    print("Start node received:", state["message"])
    # Process or pass the message to the end node
    return {"message": state["message"] + " -> processed by start"}

# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# Build the graph
builder = StateGraph(MyState)


# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# %%
builder = StateGraph(MyState)

# %%
# Add nodes
builder.add_node("start", start_node)
builder.add_node("end", end_node)

# %%
# Define the flow
builder.set_entry_point("start")
builder.add_edge("start", "end")
builder.add_edge("end", END)  # END is a special marker for graph completion

# %%
# Compile the graph
graph = builder.compile()

# Run the graph
result = graph.invoke({"message": "Hello LangGraph"})
print("Final result:", result["message"])
# Out:
# Start node received: Hello LangGraph
# End node received: Hello LangGraph -> processed by start
# Final result: Hello LangGraph -> processed by start
