# %%
r=5
r
# Out:
# 5

# %%
5 = r
# Out:
#   Cell In[2], line 1
#     5 = r
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
p1 = 20
p1
# Out:
# 20

# %%
a = 45
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 a = 45
# ----> 2 A
#
# NameError: name 'A' is not defined

# %%
a
# Out:
# 45

# %%
a@ = 56
a@
# Out:
#   Cell In[6], line 1
#     a@ = 56
#        ^
# SyntaxError: invalid syntax

# %%
a_=6
a_
# Out:
# 6

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
If = 56
If
# Out:
# 56

# %%
i = 5 
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
petrol = 110.34
petrol
type(petrol)
# Out:
# float

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
c = 10+20j
c
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
'naresh it'
# Out:
# 'naresh it'

# %%
"naresh it"
# Out:
# 'naresh it'

# %%
"naresh
 it"
# Out:
#   Cell In[24], line 1
#     "naresh
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''naresh 
it'''
# Out:
# 'naresh \nit'

# %%
#EXCEPTION HANDLING

# %%
a=5
b=2
print(a/b)
# Out:
# 2.5

# %%
a=5
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 a=5
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
a=5
b=0
try:
    print(a/b)
except Exception as e:
    print("An error occuranced:",e)
# Out:
# An error occuranced: division by zero

# %%
a=5
b=0
try:
    print(a/b)
except Exception:
    print("An error occuranced:",e)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 4
#       3 try:
# ----> 4     print(a/b)
#       5 except Exception:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4     print(a/b)
#       5 except Exception:
# ----> 6     print("An error occuranced:",e)
#
# NameError: name 'e' is not defined

# %%
num1=20
num2=30
add=num1+num2
print('The addition of {} and {} is={}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is=50

# %%
print('hello')
print('good morning')
# Out:
# hello
# good morning

# %%
print('hello', end=' ')
print('good morning')
# Out:
# hello good morning

# %%
#python function

# %%
def greet():
    print('good morning')

# %%
def greet():
    print('good morning')
greet()
# Out:
# good morning

# %%
def greet():
    print('good morning')
greet()
def greet():
    print('good morning')
greet()
# Out:
# good morning
# good morning

# %%
def greet():
    print('good morning')
    print('good afternoon')
greet()
greet()
greet()
# Out:
# good morning
# good afternoon
# good morning
# good afternoon
# good morning
# good afternoon

# %%
#with argument
def add(a,b):
    c=a+b
    print(c)
add(3,2)
# Out:
# 5

# %%
#with argument
def add(a,b):
    c=a+b
    print(c)
add(3,2,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3     c=a+b
#       4     print(c)
# ----> 5 add(3,2,1)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
#with argument
def add(a,b):
    c=a+b
    print(c)
r=add(3,2)
print(r)
type(r)
# Out:
# 5
# None
# NoneType

# %%
#with argument
def add(a,b):
    c=a+b
    return c
r=add(3,2)
print(r)
type(r)
# Out:
# 5
# int

# %%
def company(name,age):
    print('nit')
    print(23)
company('nit',23)
# Out:
# nit
# 23

# %%
def company(name,age):
    print('nit')
    print(23)
company('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2     print('nit')
#       3     print(23)
# ----> 4 company('nit')
#
# TypeError: company() missing 1 required positional argument: 'age'

# %%
def company(name,age):
    print('nit')
    print(23)
company(23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2     print('nit')
#       3     print(23)
# ----> 4 company(23)
#
# TypeError: company() missing 1 required positional argument: 'age'

# %%
def company(name,age):
    print('nit')
    print(23+1)
company('nit',23)
# Out:
# nit
# 24

# %%
def company(name,age):
    print(name)
    print(age)
company(23,'nit')
# Out:
# nit
# 23

# %%
def company(name,age):
    print(name)
    print(age+1)
company(23,'nit')
# Out:
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2     print(name)
#       3     print(age+1)
# ----> 4 company(23,'nit')
#
# Cell In[29], line 3, in company(name, age)
#       1 def company(name,age):
#       2     print(name)
# ----> 3     print(age+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def company(name,age):
    print(name)
    print(age+1)
company(age=23,name='nit')
# Out:
# nit
# 24

# %%
def company(name,age,mob):
    print(name)
    print(age+1)
company(age=23,name='nit',456)
# Out:
#   Cell In[31], line 4
#     company(age=23,name='nit',456)
#                                  ^
# SyntaxError: positional argument follows keyword argument
